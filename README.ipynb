# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronRM9416/Platform-Performance-Gaming-/blob/main/README.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Global Gaming Sales
# ## Predicting Global Sales based on various features(platform, critic score,
#
# **Author**: Aaron Musselwhite
# ##Business problem: What drives Game Sales?
#
#
#
#
# ### Data:
# a collection of Game sales based on the Publisher, the Platform, Sales, etc...
#
#     Platform         Platform Played on
#
#     Year_of_Release  Year game was released
#
#     Genre            Type of game
#
#     Publisher        Company publishing game
#
#     Global_Sales     Global Sales
#
#     Critic_Score     Gaming Critic's review score
#
#     User_Score       Consumer review score
#
#     Developer        Consumer review score
#
#
# ## Methods
#     Load Data
#
#     Data Cleaning (missing values, duplicates, nans)
#
#     Exploratory Visuals
#
#     Explantatory Visuals
#
#     Machine Learning
#
#     Preprocessing
#
#     Train/Test Split
#
#     Dummy Regression
#
#     Linear Regression
#
#     Decision Tree Regression
#
#     PCA
#
#
#
# # *Critic Score By Platform*
# ![image.png](data:image/png;base64,...)
#
#  Here we can see a fairly solid average score for Microsoft's Xbox one and Sony's PS4 marking them as the best performing out of both compainies respective collection, with PC barely topping both. However, all of them were demolished by the Sega's final game system, The DreamCast.
#
#
# ![image.png](data:image/png;base64,...)
#
#
#  While the critic scores dont get exceptionally or high, on average Critics seem to lean more towards RPGs for their best scores. However, Rpgs only slightly out perform Sports and Strategy with fighting games close behind them.
#
#
# ## *Gaming Sales By Platform and Platform Release Year*
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
# in terms of sales Nintendo has had the most success with both the GameBoy and the NES. and based on the timeline a big part of that was thanks to a lack of real competition. Since then the market has been flooded a bit with the sales now spread out amongst Sony, Microsoft, and Nintendo fairly evenly.
#
# ## Decision Tree
#
#
# i chose the Decision Tree Regressor. While not exceptionally accurate on this dataset, it is a rather tight fit and molded very well to the data it was given
#
# ## Recommendations:
#
# A big Driver is innovation, what i was able to see from the visuals and my data was that (in most cases) improvement in hardware = improvement in sales.
#
# ## Limitations & Next Steps:
#
# Lots of data to sift through and a lot of missing values.
# Re-evaluation is next step
#
#
#
# ### For further information
#
#
# For any additional questions, please contact **armusselwhite@gmail.com**
