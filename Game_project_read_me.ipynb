# %% [markdown]
# # Gaming Platform Performance
# ## predicting platform based on sales and reviews
#
# **Author**: Aaron Musselwhite
# ##Business problem:
# What Platforms are performing highest
#
#
# ### Data:
# a collection of Game sales based on the Publisher, the Platform, Sales, etc...
#
#  0   Name           - Name of game
#
#  1   Platform       - Platform Played on
#
#  2   Publisher      - Company Publishing Game
#
#  3   NA_Sales       - North American Sales
#
#  4   EU_Sales       - European Sales
#
#  5   JP_Sales       - Japan Sales
#
#  6   Global_Sales   - Global Sales
#
#  7   Critic_Score   - Gaming Critic's review score
#
#  8   User_Score     - Consumer review score
#
#
# ## Methods
# Load Data
#
# Data Cleaning (missing values, duplicates, nans)
#
# Exploratory Visuals
#
# Explantatory Visuals
#
# Machine Learning
#
# Preprocessing
#
# Train/Test Split
#
# Classification Metrics
#
# PCA
#
# ## Results
#
# #### *Critic Score By Platform (before imputation)*
# ![image.png](data:image/png;base64,...)
#
# #### *Critic Score By Platform (after imputation)*
# ![image.png](data:image/png;base64,...)
#
#  While Critics rarely just straight up bomb a game (there are some) for the most part it is pretty standard across the industry. However, Nintendo released some of the most recognizable hand held games of the time and but was out classed by Sega's final venture into gaming with the Dreamcast in terms of Critic reviewed Games.(Anyone heard of Sonic Adventure?) With the rise of the PC gamer, just about every publisher tries to atleast release a version on the platform and some of the highest rated games these days are PC only thanks to their processing power.
#
#
# ## *Gaming Sales By Platform*
#
# ![image.png](data:image/png;base64,...)
#
#
#  based on the sales alone, Nintendo has had major success with a collection of their more famous platforms. With the N64 and NES, they were some of the most technologically advanced gaming systems of the time. Followed up by their venture into handheld gaming with the DS and The Gameboy and its off shoots(Gameboy color, Gameboy advance, etc..) they did something that no one else was really doing at the time and it paid dividends. What do they know that we dont?
#
# ## Decision Tree
#
#
# i chose the Decision Tree Classifier. While i had some trouble due to the size of the data my best model post tuning and PCA was the Decision Tree
#
# ## Recommendations:
# Seek more innovation. Two of the biggest jumps on here were between Nintendo's Trend Setting and Sega's innovation out of desperation. Complacency leads to mediocre product and while sometimes it works out for the best, You may miss out on a gold mine
#
#
#
# ## Limitations & Next Steps:
#
# Lots of data to sift through and a lot of missing values.
# Re-evaluation is next step
#
#
#
# ### For further information
#
#
# For any additional questions, please contact **armusselwhite@gmail.com**
